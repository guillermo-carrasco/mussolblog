# %% [markdown]
# #Genomics reference data: the eternal problem
# This is the Python code I used for the analysis of the data. You can find Genomics_Reference_Data-Form_responses.tsv of my GitHub together with this file. The file on GitHub already has the personal information removed.
#
# ## Load responses file and remove personal data

# %%
import csv

responses = []
with open('Genomics_Reference_Data-Form_responses.tsv', 'rb') as fh:
    _responses = csv.reader(fh, delimiter='\t')
    for row in _responses:
        # Remove columns 2 and 3 (name and email address of the participant)
        _row = row[:1] + row[3:]
        responses.append(_row)

# Save the responses file without personal information to share on GitHub :-)
with open('Genomics_Reference_Data-Form_responses_no_personal.tsv', 'wb') as fh:
    _responses = csv.writer(fh, delimiter='\t')
    for row in responses:
        _responses.writerow(row)

# %% [markdown]
# Load and study the data, first exploration:

# %%
import pandas as pd

# Dates are in the format DD/MM/YY H, so you need to tell Pandas about it, or it will treat
# the date and hour as separate columns
responses = pd.read_csv('Genomics_Reference_Data-Form_responses_no_personal.tsv', sep='\t',
                 parse_dates={'timestamp': [0]})

# %%
responses
# Out:
#              timestamp  \
# 0  2014-07-07 17:45:29
# 1  2014-07-07 17:53:52
# 2  2014-07-07 18:02:02
# 3  2014-07-07 18:03:42
# 4  2014-07-07 18:07:59
# 5  2014-07-07 18:26:52
# 6  2014-07-07 19:05:14
# 7  2014-07-07 19:07:12
# 8  2014-07-07 19:08:36
# 9  2014-07-07 19:08:48
# 10 2014-07-07 19:52:20
# 11 2014-07-07 20:50:48
# 12 2014-07-07 21:11:50
# 13 2014-07-07 21:42:29
# 14 2014-07-07 23:31:51
# 15 2014-07-07 23:40:30
# 16 2014-08-07 00:03:36
# 17 2014-08-07 01:07:29
# 18 2014-08-07 09:05:51
# 19 2014-08-07 09:09:19
# 20 2014-09-07 05:02:27
# 21 2014-09-07 07:06:17
# 22 2014-09-07 14:32:37
# 23 2014-09-07 15:38:57
# 24 2014-09-07 22:59:39
# 25 2014-09-07 23:05:57
# 26 2014-09-07 23:09:31
# 27 2014-09-07 23:19:21
# 28 2014-09-07 23:31:00
# 29 2014-10-07 09:18:30
# 30 2014-10-07 10:20:31
# 31 2014-10-07 13:30:17
# 32 2014-10-07 14:07:18
# 33 2014-10-07 14:12:13
# 34 2014-10-07 15:29:40
# 35 2014-10-07 16:33:27
# 36 2014-11-07 13:39:35
# 37 2014-11-07 18:22:09
# 38 2014-12-07 08:11:11
# 39 2014-12-07 19:43:26
# 40 2014-12-07 22:06:51
#
#    Do you work only with one species, or several species' genomes?  \
# 0                                     Several species
# 1                                     Several species
# 2                                     Several species
# 3                                     Several species
# 4                                     Only one specie
# 5                                     Several species
# 6                                     Several species
# 7                                     Only one specie
# 8                                     Only one specie
# 9                                     Several species
# 10                                    Several species
# 11                                    Several species
# 12                                    Several species
# 13                                    Only one specie
# 14                                    Only one specie
# 15                                    Several species
# 16                                    Several species
# 17                                    Several species
# 18                                    Several species
# 19                                    Several species
# 20                                    Only one specie
# 21                                    Several species
# 22                                    Several species
# 23                                    Several species
# 24                                    Several species
# 25                                    Several species
# 26                                    Only one specie
# 27                                    Several species
# 28                                    Several species
# 29                                    Several species
# 30                                    Several species
# 31                                    Several species
# 32                                    Several species
# 33                                    Several species
# 34                                    Several species
# 35                                    Several species
# 36                                    Several species
# 37                                    Several species
# 38                                    Several species
# 39                                    Several species
# 40                                    Several species
#
#    What kind of reference data do you use for your research?  \
# 0   Reference genome (FASTA files), Index files (B...
# 1   Reference genome (FASTA files), Index files (B...
# 2   Reference genome (FASTA files), Index files (B...
# 3   Reference genome (FASTA files), Index files (B...
# 4   Reference genome (FASTA files), Index files (B...
# 5   Reference genome (FASTA files), Index files (B...
# 6   Reference genome (FASTA files), Index files (B...
# 7   Reference genome (FASTA files), Index files (B...
# 8   Reference genome (FASTA files), Variant Callin...
# 9   Reference genome (FASTA files), Variant Callin...
# 10  Reference genome (FASTA files), Index files (B...
# 11  Reference genome (FASTA files), Index files (B...
# 12                     Reference genome (FASTA files)
# 13  Reference genome (FASTA files), Index files (B...
# 14  Reference genome (FASTA files), Index files (B...
# 15  Reference genome (FASTA files), Index files (B...
# 16  Reference genome (FASTA files), Genetic Variat...
# 17  Reference genome (FASTA files), Variant Callin...
# 18  Reference genome (FASTA files), Index files (B...
# 19  Reference genome (FASTA files), Index files (B...
# 20  Reference genome (FASTA files), Variant Callin...
# 21  Reference genome (FASTA files), Index files (B...
# 22  Reference genome (FASTA files), Index files (B...
# 23  Reference genome (FASTA files), Variant Callin...
# 24  Reference genome (FASTA files), Index files (B...
# 25  Reference genome (FASTA files), Index files (B...
# 26  Reference genome (FASTA files), Index files (B...
# 27  Reference genome (FASTA files), Index files (B...
# 28  Reference genome (FASTA files), Index files (B...
# 29  Reference genome (FASTA files), Index files (B...
# 30  Reference genome (FASTA files), Gene Transfer ...
# 31  Reference genome (FASTA files), Index files (B...
# 32  Reference genome (FASTA files), Index files (B...
# 33  Reference genome (FASTA files), Index files (B...
# 34  Reference genome (FASTA files), Index files (B...
# 35  Reference genome (FASTA files), Index files (B...
# 36  Reference genome (FASTA files), Index files (B...
# 37  Reference genome (FASTA files), Index files (B...
# 38  Reference genome (FASTA files), Index files (B...
# 39  Reference genome (FASTA files), Index files (B...
# 40  Reference genome (FASTA files), Index files (B...
#
#                    Where do you fetch your data from?  \
# 0          ENSEMBL, BioMart (http://www.ensembl.org/)
# 1   ENSEMBL, BioMart (http://www.ensembl.org/), UC...
# 2   ENSEMBL, BioMart (http://www.ensembl.org/), UC...
# 3   ENSEMBL, BioMart (http://www.ensembl.org/), UC...
# 4   UCSC (https://genome.ucsc.edu/), NCBI (http://...
# 5                     UCSC (https://genome.ucsc.edu/)
# 6   ENSEMBL, BioMart (http://www.ensembl.org/), UC...
# 7   ENSEMBL, BioMart (http://www.ensembl.org/), UC...
# 8   ENSEMBL, BioMart (http://www.ensembl.org/), UC...
# 9           NCBI (http://www.ncbi.nlm.nih.gov/genome)
# 10  ENSEMBL, BioMart (http://www.ensembl.org/), UC...
# 11  UCSC (https://genome.ucsc.edu/), various plant...
# 12          NCBI (http://www.ncbi.nlm.nih.gov/genome)
# 13  UCSC (https://genome.ucsc.edu/), NCBI (http://...
# 14  ENSEMBL, BioMart (http://www.ensembl.org/), UC...
# 15  NCBI (http://www.ncbi.nlm.nih.gov/genome), Phy...
# 16  ENSEMBL, BioMart (http://www.ensembl.org/), UC...
# 17          NCBI (http://www.ncbi.nlm.nih.gov/genome)
# 18         ENSEMBL, BioMart (http://www.ensembl.org/)
# 19         ENSEMBL, BioMart (http://www.ensembl.org/)
# 20  ENSEMBL, BioMart (http://www.ensembl.org/), NC...
# 21  ENSEMBL, BioMart (http://www.ensembl.org/), UC...
# 22  ENSEMBL, BioMart (http://www.ensembl.org/), UC...
# 23  ENSEMBL, BioMart (http://www.ensembl.org/), UC...
# 24  ENSEMBL, BioMart (http://www.ensembl.org/), UC...
# 25  ENSEMBL, BioMart (http://www.ensembl.org/), UC...
# 26         ENSEMBL, BioMart (http://www.ensembl.org/)
# 27  ENSEMBL, BioMart (http://www.ensembl.org/), UC...
# 28  IGenome (http://support.illumina.com/sequencin...
# 29  ENSEMBL, BioMart (http://www.ensembl.org/), UC...
# 30  ENSEMBL, BioMart (http://www.ensembl.org/), UC...
# 31  ENSEMBL, BioMart (http://www.ensembl.org/), UC...
# 32  ENSEMBL, BioMart (http://www.ensembl.org/), UC...
# 33  UCSC (https://genome.ucsc.edu/), IGenome (http...
# 34  ENSEMBL, BioMart (http://www.ensembl.org/), UC...
# 35  ENSEMBL, BioMart (http://www.ensembl.org/), UC...
# 36  ENSEMBL, BioMart (http://www.ensembl.org/), UC...
# 37  UCSC (https://genome.ucsc.edu/), IGenome (http...
# 38  ENSEMBL, BioMart (http://www.ensembl.org/), UC...
# 39  ENSEMBL, BioMart (http://www.ensembl.org/), UC...
# 40  ENSEMBL, BioMart (http://www.ensembl.org/), UC...
#
#                  How do you fetch the reference data?  \
# 0                 I download the data manually myself
# 1                 I download the data manually myself
# 2   Combination of manual work and automated pipeline
# 3   Combination of manual work and automated pipeline
# 4   Combination of manual work and automated pipeline
# 5   Combination of manual work and automated pipeline
# 6   I use an automated pipeline for fetching the data
# 7   Combination of manual work and automated pipeline
# 8                 I download the data manually myself
# 9   Combination of manual work and automated pipeline
# 10  Combination of manual work and automated pipeline
# 11  Combination of manual work and automated pipeline
# 12  I use an automated pipeline for fetching the data
# 13  Combination of manual work and automated pipeline
# 14  I use an automated pipeline for fetching the data
# 15                I download the data manually myself
# 16  Combination of manual work and automated pipeline
# 17  Combination of manual work and automated pipeline
# 18                I download the data manually myself
# 19  I use an automated pipeline for fetching the data
# 20  Combination of manual work and automated pipeline
# 21  I use an automated pipeline for fetching the data
# 22  Combination of manual work and automated pipeline
# 23                I download the data manually myself
# 24  Combination of manual work and automated pipeline
# 25                I download the data manually myself
# 26  I use an automated pipeline for fetching the data
# 27                I download the data manually myself
# 28  Combination of manual work and automated pipeline
# 29  Combination of manual work and automated pipeline
# 30  Combination of manual work and automated pipeline
# 31  Combination of manual work and automated pipeline
# 32  Combination of manual work and automated pipeline
# 33                I download the data manually myself
# 34  Combination of manual work and automated pipeline
# 35                I download the data manually myself
# 36                I download the data manually myself
# 37                I download the data manually myself
# 38  I use an automated pipeline for fetching the data
# 39  Combination of manual work and automated pipeline
# 40  Combination of manual work and automated pipeline
#
#    Do you use any of these tools for downloading reference data?  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Cloudbiolinux (http://cloudbiolinux.org/), Cos...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6           Cloudbiolinux (http://cloudbiolinux.org/)
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10          Cloudbiolinux (http://cloudbiolinux.org/)
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                       Bioconductor
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20          Cloudbiolinux (http://cloudbiolinux.org/)
# 21          Cloudbiolinux (http://cloudbiolinux.org/)
# 22  In house stuff, but looking for stable alterna...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                             custom
# 27                                                NaN
# 28      rsync whole directory structure from igenomes
# 29  wget, curl, Rcurl (R package), biomaRt (R pack...
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
#
#       How do you keep your reference data up to date?  \
# 0   Staying consistent with versions of references...
# 1   Generally only want to use one version for a g...
# 2   I regularly check for new updates and fetch th...
# 3                                                 NaN
# 4                                             I don't
# 5   I regularly check for new updates and fetch th...
# 6   I use one of the aforementioned tools to autom...
# 7   I regularly check for new updates and fetch th...
# 8   I regularly check for new updates and fetch th...
# 9   I regularly check for new updates and fetch th...
# 10  I regularly check for new updates and fetch th...
# 11                                                NaN
# 12  I regularly check for new updates and fetch th...
# 13  I regularly check for new updates and fetch th...
# 14  I use one of the aforementioned tools to autom...
# 15  I regularly check for new updates and fetch th...
# 16  only when need, prefer working with one versio...
# 17                                                NaN
# 18  I infrequently check for new updates and fetch...
# 19  I regularly check for new updates and fetch th...
# 20                   cron+wget/rsync for most sources
# 21  I use one of the aforementioned tools to autom...
# 22  I use one of the aforementioned tools to autom...
# 23                                                NaN
# 24  I regularly check for new updates and fetch th...
# 25  I regularly check for new updates and fetch th...
# 26  I use one of the aforementioned tools to autom...
# 27   when i remember or someone needs a newer version
# 28  do manual check : Most of the time we stick to...
# 29                                        custom tool
# 30  I regularly check for new updates and fetch th...
# 31                        regular downloads quarterly
# 32  I regularly check for new updates and fetch th...
# 33  I regularly check for new updates and fetch th...
# 34  I regularly check for new updates and fetch th...
# 35                          Update as projects demand
# 36  I update data when I start a new project, but ...
# 37  I regularly check for new updates and fetch th...
# 38                                custom cron scripts
# 39          following the corresponding mailing lists
# 40                     check at start of new projects
#
#                                  Comments / Questions  \
# 0                                                 NaN
# 1                                                 NaN
# 2   I'd really enjoy reading the summary results f...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   We use versioning and we stick to only one set...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16  The result of the analysis might change a lot ...
# 17                                                NaN
# 18  At Babraham we mostly worked on human and mous...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22       Any way you will make the results available?
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                          It's definitely a pain :)
# 28  Bacterial genomes : I downloaded from ncbi and...
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
#
#               How do you structure the reference data  \
# 0   I keep the same structure than the original so...
# 1                                                 NaN
# 2                         I use a different structure
# 3                         I use a different structure
# 4                         I use a different structure
# 5                         I use a different structure
# 6                         I use a different structure
# 7                         I use a different structure
# 8   I keep the same structure than the original so...
# 9   I keep the same structure than the original so...
# 10  I keep the same structure than the original so...
# 11                        I use a different structure
# 12  I keep the same structure than the original so...
# 13                        I use a different structure
# 14  I keep the same structure than the original so...
# 15  I keep the same structure than the original so...
# 16                        I use a different structure
# 17                        I use a different structure
# 18                        I use a different structure
# 19  I keep the same structure than the original so...
# 20                        I use a different structure
# 21                        I use a different structure
# 22  I keep the same structure than the original so...
# 23                        I use a different structure
# 24                        I use a different structure
# 25  I keep the same structure than the original so...
# 26  I keep the same structure than the original so...
# 27                        I use a different structure
# 28  I keep the same structure than the original so...
# 29                        I use a different structure
# 30  I keep the same structure than the original so...
# 31                        I use a different structure
# 32                        I use a different structure
# 33                        I use a different structure
# 34  I keep the same structure than the original so...
# 35                        I use a different structure
# 36                        I use a different structure
# 37                        I use a different structure
# 38                        I use a different structure
# 39  I keep the same structure than the original so...
# 40  I keep the same structure than the original so...
#
#    What motivates you to use your own structure for your reference data?  \
# 0                                                 NaN
# 1   To unify data from different sources on a comm...
# 2   Just convenience (works better with our pipeli...
# 3   To unify data from different sources on a comm...
# 4   I think it's more logical, To unify data from ...
# 5   Just convenience (works better with our pipeli...
# 6   To unify data from different sources on a comm...
# 7   I think it's more logical, To unify data from ...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  not using my own structure - borrowed it from ...
# 12                                                NaN
# 13  Just convenience (works better with our pipeli...
# 14                                                NaN
# 15                                                NaN
# 16  I think it's more logical, To unify data from ...
# 17  To unify data from different sources on a comm...
# 18  Just convenience (works better with our pipeli...
# 19                                                NaN
# 20  To unify data from different sources on a comm...
# 21  To unify data from different sources on a comm...
# 22                                                NaN
# 23  Just convenience (works better with our pipeli...
# 24  To unify data from different sources on a comm...
# 25                                                NaN
# 26                                                NaN
# 27                          I think it's more logical
# 28                                                NaN
# 29  To unify data from different sources on a comm...
# 30                                                NaN
# 31  To allow all bioinformaticians in the company ...
# 32  Just convenience (works better with our pipeli...
# 33                          I think it's more logical
# 34                                                NaN
# 35  To unify data from different sources on a comm...
# 36  To unify data from different sources on a comm...
# 37  Just convenience (works better with our pipeli...
# 38  To unify data from different sources on a comm...
# 39                                                NaN
# 40                                                NaN
#
#      Where do you store your reference data?  Personal data  \
# 0                              Local servers            NaN
# 1                              Local servers            NaN
# 2   A combination of local and cloud storage            NaN
# 3                              Local servers            NaN
# 4                              Local servers            NaN
# 5                              Local servers            NaN
# 6   A combination of local and cloud storage            NaN
# 7   A combination of local and cloud storage            NaN
# 8                              Local servers            NaN
# 9                              Local servers            NaN
# 10  A combination of local and cloud storage            NaN
# 11                             Local servers            NaN
# 12  A combination of local and cloud storage            NaN
# 13  A combination of local and cloud storage            NaN
# 14  A combination of local and cloud storage            NaN
# 15                             Local servers            NaN
# 16                             Local servers            NaN
# 17                             Local servers            NaN
# 18                             Local servers            NaN
# 19                             Local servers            NaN
# 20  A combination of local and cloud storage            NaN
# 21                             Local servers            NaN
# 22                             Local servers            NaN
# 23                             Local servers            NaN
# 24                             Local servers            NaN
# 25                             Local servers            NaN
# 26                             Local servers            NaN
# 27                             Local servers            NaN
# 28                             Local servers            NaN
# 29                             Local servers            NaN
# 30                             Local servers            NaN
# 31                             Local servers            NaN
# 32                             Local servers            NaN
# 33                             Local servers            NaN
# 34                             Local servers            NaN
# 35                             Local servers            NaN
# 36                             Local servers            NaN
# 37                             Local servers            NaN
# 38                             Local servers            NaN
# 39                             Local servers            NaN
# 40                             Local servers            NaN
#
#     Untitled Question [Row 2]
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13                        NaN
# 14                        NaN
# 15                        NaN
# 16                        NaN
# 17                        NaN
# 18                        NaN
# 19                        NaN
# 20                        NaN
# 21                        NaN
# 22                        NaN
# 23                        NaN
# 24                        NaN
# 25                        NaN
# 26                        NaN
# 27                        NaN
# 28                        NaN
# 29                        NaN
# 30                        NaN
# 31                        NaN
# 32                        NaN
# 33                        NaN
# 34                        NaN
# 35                        NaN
# 36                        NaN
# 37                        NaN
# 38                        NaN
# 39                        NaN
# 40                        NaN

# %% [markdown]
# ## Participation

# %%
import datetime

participation = responses.groupby(responses['timestamp'].map(lambda x: datetime.date(x.year, x.month, x.day)))

# %%
participation.count()['timestamp']
# Out:
# timestamp
# 2014-07-07    16
# 2014-08-07     4
# 2014-09-07     9
# 2014-10-07     7
# 2014-11-07     2
# 2014-12-07     3
# Name: timestamp, dtype: int64

# %%
participation.count()['timestamp'].plot(kind='bar', title='Survey participation', grid=False)

# %% [markdown]
# ## The questions
#
# _Do you work only with one species, or several species' genomes?_

# %%
species = responses['Do you work only with one species, or several species\' genomes?']

# %%
species.value_counts().plot(kind='pie', autopct='%1.1f%%', title='Do yuo work with single or multiple species', figsize=(7,7))

# %% [markdown]
# _What kind of reference data do you use for your research?_
#
# Will group the data in tearms of: How many groups use each kind of reference data?

# %%
ref_data_groups = responses['What kind of reference data do you use for your research?']

# %%
import re

ref_data = {}
for group in ref_data_groups:
    # Nasty parsing due to the wrong design of the survey, shame on me...
    # Remove everything within parenthesis and then split by comma
    group =re.sub(r'\([^)]*\)', '', group)
    data = group.split(',')
    for key in data:
        if ref_data.has_key(key):
            ref_data[key] += 1
        else:
            ref_data[key] = 1

# %%
df_ref_data = pd.DataFrame.from_dict(ref_data, orient='index')
df_ref_data
# Out:
#                                         0
#  Variant Calling data                  26
#  Structural variantion data             1
#  Annotation data                       22
#  Genetic Variation data                23
# Reference genome                       41
#  Index files                           33
#  Complete Genomics                      1
#  GATK bundle                            1
#  hand-made annotation tab-delim files   1
#  Gene Transfer data                    26
#  BED-detail files                       1

# %%
df_ref_data = df_ref_data.sort(columns=0)
plot = df_ref_data.plot(kind='barh', legend=False, grid=False, title='Number of groups using each kind of reference data',
                 figsize=(10,10))

# %% [markdown]
# _Where do you fetch your reference data from?_

# %%
ref_data_locations = {}
for loc in responses['Where do you fetch your data from?']:
    # Nasty parsing due to the wrong design of the survey, shame on me...
    # Remove everything within parenthesis and then split by comma
    loc =re.sub(r'\([^)]*\)', '', loc)
    data = loc.split(',')
    for key in data:
        if ref_data_locations.has_key(key):
            ref_data_locations[key] += 1
        else:
            ref_data_locations[key] = 1
del(ref_data_locations[' etc.'])

# %%
df_ref_loc = pd.DataFrame.from_dict(ref_data_locations, orient='index')
df_ref_loc.sort(columns=0, ascending=False)
# Out:
#                                   0
#  BioMart                         30
# ENSEMBL                          30
#  UCSC                            25
#  NCBI                            21
#  IGenome                         15
# UCSC                              6
# NCBI                              4
#  Phytozome                        2
#  BeeBase                          1
# IGenome                           1
#  http://genomeinabottle.org/      1
#  TAIR                             1
#  IMG                              1
#  RGD                              1
#  JGI...                           1
#  various plant genome databases   1
#  MG-RAST                          1

# %%
df_ref_loc = df_ref_loc.sort(columns=0)
plot = df_ref_loc.plot(kind='barh', legend=False, grid=False, title='Where do you fetch your data from?',
                 figsize=(10,10))
